# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

print("RoadSense AI Environment Ready 🚀")
# Out:
# RoadSense AI Environment Ready 🚀
